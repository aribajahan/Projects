# %%
import pandas as pd
import numpy
from sklearn.naive_bayes import MultinomialNB
lemon_train = pd.read_csv('Lesson11data/lemon_training.csv', index_col= 'RefId')
% pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
lemon_train.describe()
# Out:
#            IsBadBuy       VehYear    VehicleAge   WheelTypeID         VehOdo  \
# count  51088.000000  51088.000000  51088.000000  48819.000000   51088.000000
# mean       0.123101   2005.345893      4.172780      1.494992   71550.864880
# std        0.328557      1.727976      1.709315      0.521792   14610.426618
# min        0.000000   2001.000000      0.000000      0.000000    5368.000000
# 25%        0.000000   2004.000000      3.000000      1.000000   61866.750000
# 50%        0.000000   2005.000000      4.000000      1.000000   73434.500000
# 75%        0.000000   2007.000000      5.000000      2.000000   82478.000000
# max        1.000000   2010.000000      9.000000      3.000000  115717.000000
#
#        MMRAcquisitionAuctionAveragePrice  MMRAcquisitionAuctionCleanPrice  \
# count                       51076.000000                     51076.000000
# mean                         6130.263999                      7376.365671
# ...

# %%
lemon_train.head(10)
# Out:
#        IsBadBuy   PurchDate Auction  VehYear  VehicleAge        Make  \
# RefId
# 1             0   12/7/2009   ADESA     2006           3       MAZDA
# 2             0   12/7/2009   ADESA     2004           5       DODGE
# 5             0   12/7/2009   ADESA     2005           4        FORD
# 6             0   12/7/2009   ADESA     2004           5  MITSUBISHI
# 7             0   12/7/2009   ADESA     2004           5         KIA
# 13            1  12/14/2009   ADESA     2005           4       DODGE
# 15            0  12/14/2009   ADESA     2006           3       DODGE
# 16            0  12/14/2009   ADESA     2003           6   CHEVROLET
# 17            0  12/14/2009   ADESA     2005           4   CHEVROLET
# 18            0  12/14/2009   ADESA     2003           6      SATURN
#
#                       Model Trim           SubModel   Color Transmission  \
# RefId
# 1                    MAZDA3    i         4D SEDAN I     RED         AUTO
# ...

# %%
print lemon_train['Transmission'].unique()
# Out:
# ['AUTO' 'MANUAL' nan 'Manual']

# %%
replace 'Manual' with 'MANUAL'
lemon_train('Transmission_Fixed'] = lemon_train['Transmission']
            lemon_train['Transmission' == 'Manual'] = 'MANUAL'
            lemon_train.groupby('Transmission_Fixed').count()
# Out:
#   File "<ipython-input-5-13a02b4a0871>", line 1
#     replace 'Manual' with 'MANUAL'
#                    ^
# SyntaxError: invalid syntax

# %%
print lemon_train.groupby('Make').count()

# %% [markdown]
# There are missing data in columns: Trim, Wheeltype
# Might be because Luxury cars dont release that info or don't have that
#
# Trim could be a good way to figure out if a car is a luxury car or not.

# %%
print lemon_train['Model'].unique()

# %%
set([a.split()[0] for a in lemon_train['Model'].values])

# %%
lemon_train.VehicleAge.hist()

# %%
from matplotlib import pyplot as plt



plt.scatter(lemon_train.VehYear, lemon_train.VehicleAge)

# %%
print plt.scatter(lemon_train.VehOdo, lemon_train.VehicleAge)

# %%
print plt.hist(lemon_train.VehicleAge.values)
# Out:
# (array([  1.00000000e+00,   2.15900000e+03,   5.93600000e+03,
#          1.11580000e+04,   1.19690000e+04,   9.06400000e+03,
#          5.57700000e+03,   3.23400000e+03,   1.53200000e+03,
#          4.58000000e+02]), array([ 0. ,  0.9,  1.8,  2.7,  3.6,  4.5,  5.4,  6.3,  7.2,  8.1,  9. ]), <a list of 10 Patch objects>)

# %%
# Out:
# (array([  1.86000000e+03,   3.49680000e+04,   1.41400000e+04,
#          1.10000000e+02,   3.00000000e+00,   1.00000000e+00,
#          1.00000000e+00,   1.00000000e+00,   1.00000000e+00,
#          3.00000000e+00]), array([  1.00000000e+00,   3.87940000e+03,   7.75780000e+03,
#          1.16362000e+04,   1.55146000e+04,   1.93930000e+04,
#          2.32714000e+04,   2.71498000e+04,   3.10282000e+04,
#          3.49066000e+04,   3.87850000e+04]), <a list of 10 Patch objects>)

# %%
lemon_train['MilesPerYear'] = lemon_train['VehOdo'].values / (lemon_train['VehicleAge'].values + 1)

np.log(lemon_train['MilesPerYear']).hist(bins=30)

# %% [markdown]
# so when only calling the column, it keeps it as an object part of pandas series. But if you call .values you call the ndarray and now you can handle them as numbers.

# %%
print plt.hist(lemon_train.VehBCost.values)
# Out:
# (array([  1.86000000e+03,   3.49680000e+04,   1.41400000e+04,
#          1.10000000e+02,   3.00000000e+00,   1.00000000e+00,
#          1.00000000e+00,   1.00000000e+00,   1.00000000e+00,
#          3.00000000e+00]), array([  1.00000000e+00,   3.87940000e+03,   7.75780000e+03,
#          1.16362000e+04,   1.55146000e+04,   1.93930000e+04,
#          2.32714000e+04,   2.71498000e+04,   3.10282000e+04,
#          3.49066000e+04,   3.87850000e+04]), <a list of 10 Patch objects>)

# %%
print plt.scatter(lemon_train.VehBCost, lemon_train.MMRAcquisitionAuctionAveragePrice)

# %% [markdown]
# The price at which cars were bought at is linearly related to the price set at average quality.

# %%
print plt.scatter(lemon_train.VehBCost, lemon_train.MMRAcquisitionAuctionCleanPrice)

# %%
print plt.scatter(lemon_train.MMRAcquisitionAuctionCleanPrice, lemon_train.MMRAcquisitionAuctionAveragePrice)

# %%
print plt.scatter(lemon_train.VehBCost.values, (lemon_train['VehOdo'].values / (lemon_train['VehicleAge'].values + 1)))

# %% [raw]
# VehBcost compared to AcquisitionPrices, most cars alove avg price.
# vehicle size = collapse values
#
# "small truck" = "truck"
#
# def carsize(x):
# if x = "smalltruck"
# return "truck"
#
# submodel
# # of doors?
# Risk factor: warranty/vehbcost
#
# average price vs clean price vs vehbcost
#
# import string- explore all the features here
# size
# color
#
# means/buyplots
# currentAcquisitionAveragePrice
#
# explore buyerID- who bought it? are they all terrible buyers?
#
# wheeltype was very interesting- if it was missing. because they were really bad buys
