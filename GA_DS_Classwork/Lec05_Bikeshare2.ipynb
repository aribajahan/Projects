# %%
# %pylab inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import f_regression
from sklearn.metrics import mean_squared_error, mean_absolute_error
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
bikeday = pd.read_csv("data/day.csv")
bikeday.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600
#
# [5 rows x 16 columns]

# %%
bikeday[['dteday', 'season', 'holiday']

# %%
bikeday[['season', 'weathersit', 'temp', 'hum', 'windspeed', 'casual', 'cnt']].describe()
# Out:
#            season  weathersit        temp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     2.496580    1.395349    0.495385    0.627894    0.190486
# std      1.110807    0.544894    0.183051    0.142429    0.077498
# min      1.000000    1.000000    0.059130    0.000000    0.022392
# 25%      2.000000    1.000000    0.337083    0.520000    0.134950
# 50%      3.000000    1.000000    0.498333    0.626667    0.180975
# 75%      3.000000    2.000000    0.655417    0.730209    0.233214
# max      4.000000    3.000000    0.861667    0.972500    0.507463
#
#             casual          cnt
# count   731.000000   731.000000
# mean    848.176471  4504.348837
# std     686.622488  1937.211452
# min       2.000000    22.000000
# 25%     315.500000  3152.000000
# 50%     713.000000  4548.000000
# 75%    1096.000000  5956.000000
# max    3410.000000  8714.000000
#
# [8 rows x 7 columns]

# %% [markdown]
# So there's 731 entries.

# %%
seasontypes = bikeday[['season','registered', 'cnt']].groupby('season')

seasontypes
#pd.DataFrame(seasontypes)

# %%
type(seasontypes)
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %%
seasontypes.describe()
# Out:
# /Users/aribajahan/anaconda/lib/python2.7/site-packages/pandas/compat/scipy.py:68: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   score = values[idx]
# /Users/aribajahan/anaconda/lib/python2.7/site-packages/pandas/compat/scipy.py:68: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   score = values[idx]
# /Users/aribajahan/anaconda/lib/python2.7/site-packages/pandas/compat/scipy.py:68: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   score = values[idx]
# /Users/aribajahan/anaconda/lib/python2.7/site-packages/pandas/compat/scipy.py:68: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   score = values[idx]
# ...

# %%
fig,ax1 = plt.subplots(1,1)

ax1.hist(bikeday.cnt, color="b")
ax1.set_title('xx')
ax1.set_xlabel("xx")
