# %%
# %pylab inline #enables plotting in the notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from pandas import * #this brings in all pandas so I don't have to type pd

# %%
#Plotting 3 different random cumulative Sums
a = randn(50).cumsum()
b = randn(50).cumsum()
c = randn(50).cumsum()

# %%
df = DataFrame({'a':a, 'b':b, 'c':c})
df

#the 'a' is the name of the column and the :a is setting that we want the 0-49 points in the columns
# Out:
#             a         b         c
# 0    1.312722  0.590473  0.872703
# 1   -0.576236  1.448169  2.036191
# 2   -1.957569  0.566626  3.041752
# 3   -1.469480  0.076145  2.186337
# 4   -1.390103 -0.140708  3.220115
# 5   -0.909468  0.336224  3.209081
# 6   -0.154647 -0.039533  2.948079
# 7   -1.925546 -0.844917  2.467474
# 8   -5.064985  0.223250  2.229124
# 9   -6.500942 -0.611155  1.891481
# 10  -6.899021 -0.817005  0.250796
# 11  -7.790740 -0.149431 -0.528307
# 12  -7.507570 -0.546842 -1.175229
# 13  -6.520022 -1.308913 -1.739021
# 14  -7.916419 -0.553034 -1.879873
# 15  -7.073754  0.244298 -1.570368
# 16  -7.389844  0.410169 -0.890837
# 17  -6.355461  0.418850 -1.411278
# 18  -6.697347  0.122699 -2.114791
# 19  -6.570776  1.949846 -2.262523
# 20  -7.181765  2.721470 -2.727746
# 21  -6.024470  1.047789 -2.737771
# 22  -4.390277  0.954546 -3.009564
# 23  -4.827433  1.765197 -1.904769
# 24  -5.048570  3.844647 -2.611853
# 25  -8.257838  4.493595 -2.362677
# ...

# %%
df.plot()

# %%
df.plot(subplots=True)
df.plot()

# %%
titanic = read_csv("data/titanic.csv")
titanic
# Out:
#     survived  pclass                                               name  \
# 0          0       3                            Braund, Mr. Owen Harris
# 1          1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1       3                             Heikkinen, Miss. Laina
# 3          1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0       3                           Allen, Mr. William Henry
# 5          0       3                                   Moran, Mr. James
# 6          0       1                            McCarthy, Mr. Timothy J
# 7          0       3                     Palsson, Master. Gosta Leonard
# 8          1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9          1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10         1       3                    Sandstrom, Miss. Marguerite Rut
# 11         1       1                           Bonnell, Miss. Elizabeth
# ...

# %%
SurvivedByClass=titanic.groupby('pclass').survived.sum()
SurvivedByClass
# Out:
# pclass
# 1         136
# 2          87
# 3         119
# Name: survived, dtype: int64

# %%
SurvivedBySex=titanic.groupby('sex').survived.sum()
SurvivedBySex
# Out:
# sex
# female    233
# male      109
# Name: survived, dtype: int64

# %%
SurvivedByClass.plot(kind='bar',title='Titanic Survivors by Class')

# %%
SurvivedBySex.plot(kind='bar',title='Titanic Survivors by Sex')

# %%
df.plot(title="Random plot",figsize=(20,8),ylim=(-2,8),kind='barh')

# %%
b = titanic["fare"] #to call only one column
b
# Out:
# 0      7.2500
# 1     71.2833
# 2      7.9250
# 3     53.1000
# 4      8.0500
# 5      8.4583
# 6     51.8625
# 7     21.0750
# 8     11.1333
# 9     30.0708
# 10    16.7000
# 11    26.5500
# 12     8.0500
# 13    31.2750
# 14     7.8542
# ...
# 876     9.8458
# 877     7.8958
# 878     7.8958
# 879    83.1583
# 880    26.0000
# 881     7.8958
# 882    10.5167
# 883    10.5000
# 884     7.0500
# 885    29.1250
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %%
titanic.fare.hist(bins=(150))
#look in to how to reduce the y limit with histogram
#There is an infinite amount of numbers, so bins help to allow grabbing more info??
#IT can help with the granularity of the graph

# %%
titanic.age.hist()

# %%
# Combine pandas plots by running them together -- if pandas thinks they can be overlapped, it will
titanic.fare.hist(bins=15, normed=True, color='lightseagreen')
titanic.fare.plot(kind='kde', xlim=(0,600), style='r--')
